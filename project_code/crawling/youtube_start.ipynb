# %%
# Import Library
import requests
from bs4 import BeautifulSoup
import time
import urllib.request
from selenium.webdriver import Chrome
import re
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import datetime as dt
from selenium.webdriver.common.by import By

from urllib import parse

from selenium import webdriver

# %% [markdown]
# ## Selenium 기본 키
#
#
# ### Selenium elements
# ```
# from selenium.webdriver.common.by import By
#
# driver.find_element(By.XPATH, '//button[text()="Some text"]')
# driver.find_element(By.XPATH, '//button')
# driver.find_element(By.ID, 'loginForm')
# driver.find_element(By.LINK_TEXT, 'Continue')
# driver.find_element(By.PARTIAL_LINK_TEXT, 'Conti')
# driver.find_element(By.NAME, 'username')
# driver.find_element(By.CSS_SELECTOR, 'p.content')
# driver.find_element(By.TAG_NAME, 'h1')
# driver.find_element(By.CLASS_NAME, 'content')
#
# driver.find_elements(By.ID, 'loginForm')
# driver.find_elements(By.CLASS_NAME, 'content')
#
# ```

# %% [markdown]
# ## BS4 기본키
#
# ```
# SELECT 설명
#
# select(), select_one()	설명
# 태그이름	태그이름으로 찾음
# .클래스이름'	클래스이름으로 찾음
# #아이디이름'	아이디이름으로 찾음 (아이디는 연속X)
# 상위태그이름>자식태그>자식태그'	부모 자식간의 태그 조회' >' 로 구분
# 상위태그이름 자손태그'	부모 자손간의 태그 조회 #띄어쓰기(공백) 로 구분 #자식을 건너 띈다.
# [속성]'	태그 안의 속성을 찾음
# 태그이름.클래스이름'	해당태그의 클래스이름을 찾음
# #아이디이름 > 태그이름.클래스이름	아이이디 이름으로 찾고 자식태그와 클래스이름으로 찾음
# ```

# %% [markdown]
# # scroll down

# %%
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

driver = Chrome()

url = 'https://www.youtube.com'
driver.get(url)
body = driver.find_element(By.CSS_SELECTOR, 'body')
for _ in range(5):
    for _ in range(7):
        body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1)

driver.quit()

# %% [markdown]
# # only Selenium

# %%
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

driver = Chrome()

url = 'https://www.youtube.com'
driver.get(url)

try:
    titles = driver.find_elements(By.ID,'video-title')
    print(titles)
    print('titles : ',titles.text)
    label = titles.get_attribute('innerHTML')
    print('html label : ',label)
    label = titles.get_attribute('innerText')
    print('text label : ',label)
except:
    print('error')
driver.quit()
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_9")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_10")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_11")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_12")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_13")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_14")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_15")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_16")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_17")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_18")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_19")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_20")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_21")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_22")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_23")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_24")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_25")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_26")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_27")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_28")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_29")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_30")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_31")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_32")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_33")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9f041a30d02da4ea1e", element="9BC2072D24D96793319381C184772575_element_34")>, <selenium.webdriver.remote.webelement.WebElement (session="796075238e209d9 ...
# error

# %%
from bs4 import BeautifulSoup
from urllib import parse

from selenium import webdriver
from selenium.webdriver.common.by import By

def test_eight_components():
    driver = webdriver.Chrome()
    
    driver.get('https://www.selenium.dev/selenium/web/web-form.html')
    
    title = driver.title
    assert title == 'Web form'
    
    driver.implicitly_wait(0.5)
    
    # text_box = driver.find_element(by=By.NAME, value='my-text')
    text_box = driver.find_element(by=By.CLASS_NAME, value='form-control')
    submit_button = driver.find_element(by=By.CSS_SELECTOR, value='button')
    
    text_box.send_keys('Selenium')
    submit_button.click()
    
    message = driver.find_element(by=By.ID, value='message')
    value = message.text
    assert value =='Received!'
    try:
        print(value)
        print(message.text)
    except:
        pass
    
    driver.quit()

if __name__=="__main__":
    test_eight_components()
    # print(len(result))
# Out:
# Received!
# Received!

# %%
try:
    soup = BeautifulSoup(driver.page_source)
    
    imgs_list = soup.select('div#contents div#content a#thumbnail') # tag이름#ID이름
    img_urls = []

    for img in imgs_list:
        try:
            xx =img.find('img')
            print(xx['src'].split('?')[0])
            img_urls.append(xx['src'].split('?')[0])
        except:
            print('image error')
    
    a_list = soup.select('div#contents div#content a#video-title-link') # tag이름#ID이름
            
    result = []
    for a_tag,img_url in zip(a_list,img_urls):
        link = parse.urljoin(url,a_tag.get('href'))
        title = a_tag['aria-label']
        result.append([link,title,img_url])
except:
    print('error exists')

#############################################################################
#############################################################################

def test2():
    driver = webdriver.Chrome()        #웹드라이버가 있는 경로에서 Chrome을 가져와 실행-> driver변수
    
    driver.get('https://www.hiphoper.com/')     #driver변수를 이용해 원하는 url 접속
    
    imgs = driver.find_elements(By.CSS_SELECTOR,'img.card__image')       #css selector를 이용해서 'tag이름.class명'의 순으로 인자를 전달
    result = []     #웹 태그에서 attribute 중 src만 담을 리스트
    
    for img in imgs:                                #모든 이미지들을 탐색
        # print(img.get_attribute('src'))         #이미지 주소를 print
        result.append(img.get_attribute('src'))     #이미지 src만 모아서 리스트에 저장
    
    driver.quit()
    
    return result

if __name__=="__main__":
    # test_eight_components()
    result = test2()
    # print(len(result))
    print(result[:7])

# %% [markdown]
# # URL and Title & Thumbnails

# %%
# Import Library
import requests
from bs4 import BeautifulSoup
import time
import urllib.request
from selenium.webdriver import Chrome
import re
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import datetime as dt
from selenium.webdriver.common.by import By

from urllib import parse

from selenium import webdriver


driver = Chrome()
url = 'https://www.youtube.com'
driver.get(url)

#################################################################################
### youtube page scroll   : java script로 동적 구성되어있기때문에, 아래로 내려줘서 정보를 로딩
#################################################################################

body = driver.find_element(By.CSS_SELECTOR, 'body')
for _ in range(5): # 5번 반복.
    for _ in range(7): # 7번 내리고 1초 쉬고,
        body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1.5)

time.sleep(2)




#################################################################################
### get image,title,url - selenium이나 bs4를 이용해서 크롤링.
#################################################################################

try:
    soup = BeautifulSoup(driver.page_source)
    
    imgs_list = soup.select('div#contents div#content a#thumbnail') # tag이름#ID이름
    img_urls = []

    for img in imgs_list:
        try:
            xx =img.find('img')
            print(xx['src'].split('?')[0])
            img_urls.append(xx['src'].split('?')[0])
        except:
            print('image error')
    
    a_list = soup.select('div#contents div#content a#video-title-link') # tag이름#ID이름
            
    result = []
    for a_tag,img_url in zip(a_list,img_urls):
        link = parse.urljoin(url,a_tag.get('href'))
        title = a_tag['aria-label']
        result.append([link,title,img_url])
except:
    print('error exists')

driver.quit()
# Out:
# https://i4.ytimg.com/vi/QSoUgVVUqBs/0.jpg
# https://i.ytimg.com/vi/x6i3_LfeTjY/hq720.jpg
# image error
# https://i.ytimg.com/vi/sJ31tuK4s74/hq720.jpg
# image error
# https://i.ytimg.com/vi/m7sD-7MzgJw/hq720.jpg
# image error
# https://i.ytimg.com/vi/vOOWvw5xIuw/hq720.jpg
# image error
# https://i.ytimg.com/vi/hyzvfVuLCLQ/hq720.jpg
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error
# image error

# %% [markdown]
# # Thumbnail

# %%
from bs4 import BeautifulSoup
from urllib import parse

driver = Chrome()
url = 'https://www.youtube.com'
driver.get(url)

# TODO: time delay.
time.sleep(5)  # 여기에서 시간을 많이줘야 가져올 수 있음. #######@@@@@@@@@@@@@ IMPORTANT !!!!!!!! @@@@@@@@@#######

soup = BeautifulSoup(driver.page_source)
a_list = soup.select('div#contents div#content a#thumbnail') # tag이름#ID이름

img_urls = []
for img in a_list:
    try:
        xx =img.find('img')
        print(xx['src'].split('?')[0])
        img_urls.append(xx['src'].split('?')[0])
    except:
        # print('no img')
        pass

driver.quit()
# Out:
# https://i1.ytimg.com/vi/e66XtC33l-o/0.jpg
# https://i.ytimg.com/vi/Hg7-o3_jAjE/hq720.jpg
# https://i.ytimg.com/vi/MxetbHsYDEs/hq720.jpg
# https://i.ytimg.com/vi/Dk8eCoJ8w6c/hq720.jpg
# https://i.ytimg.com/vi/i8AirHtVUPY/hq720.jpg
# https://i.ytimg.com/vi/gbRtnBLo__Y/hq720.jpg

# %% [markdown]
# ## 댓글 작성자, 내용 가져오기

# %%
from selenium import webdriver
import time
# from openpyxl import Workbook
import pandas as pd
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

import warnings 
warnings.filterwarnings('ignore')

driver = webdriver.Chrome()
url = 'https://www.youtube.com/watch?v=3qHl_XGnI_4'
# 서태지 : 너와 함께한 시간속에서.

url = 'https://www.youtube.com/watch?v=lakwcsprK4E'

driver.get(url)
driver.implicitly_wait(3)

time.sleep(1.5)

driver.execute_script("window.scrollTo(0, 800)")
time.sleep(3)


# 유튜브 팝업 닫기.
try:
    driver.find_element(By.CSS_SELECTOR, "#dismiss-button > a").click()
except:
    pass
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /Users/juniverse/Desktop/pointcloud/VectorUniverse/crawl/youtube_start.ipynb 셀 15 line 1
#      <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/crawl/youtube_start.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a> url = 'https://www.youtube.com/watch?v=3qHl_XGnI_4'
#      <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/crawl/youtube_start.ipynb#X20sZmlsZQ%3D%3D?line=12'>13</a> # 서태지 : 너와 함께한 시간속에서.
# ---> <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/crawl/youtube_start.ipynb#X20sZmlsZQ%3D%3D?line=13'>14</a> driver.get(url)
#      <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/crawl/youtube_start.ipynb#X20sZmlsZQ%3D%3D?line=14'>15</a> driver.implicitly_wait(3)
#      <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/crawl/youtube_start.ipynb#X20sZmlsZQ%3D%3D?line=16'>17</a> time.sleep(1.5)
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:353, in WebDriver.get(self, url)
#     351 def get(self, url: str) -> None:
#     352     """Loads a web page in the current browser session."""
# --> 353     self.execute(Command.GET, {"url": url})
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     342 response = self.command_executor.execute(driver_command, params)
#     343 if response:
# --> 344     self.error_handler.check_response(response)
#     345     response["value"] = self._unwrap_value(response.get("value", None))
#     346     return response
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: no such execution context
#   (Session info: chrome=117.0.5938.132)
# Stacktrace:
# 0   chromedriver                        0x0000000104fc8ed8 chromedriver + 5091032
# 1   chromedriver                        0x0000000104fbfc43 chromedriver + 5053507
# 2   chromedriver                        0x0000000104b5b366 chromedriver + 447334
# 3   chromedriver                        0x0000000104b41653 chromedriver + 341587
# 4   chromedriver                        0x0000000104b3f295 chromedriver + 332437
# 5   chromedriver                        0x0000000104b3f9b9 chromedriver + 334265
# 6   chromedriver                        0x0000000104b51143 chromedriver + 405827
# 7   chromedriver                        0x0000000104b68878 chromedriver + 501880
# 8   chromedriver                        0x0000000104b6ebeb chromedriver + 527339
# 9   chromedriver                        0x0000000104b40161 chromedriver + 336225
# 10  chromedriver                        0x0000000104b68564 chromedriver + 501092
# 11  chromedriver                        0x0000000104bed74c chromedriver + 1046348
# 12  chromedriver                        0x0000000104bd1433 chromedriver + 930867
# 13  chromedriver                        0x0000000104b9c042 chromedriver + 712770
# 14  chromedriver                        0x0000000104b9d26e chromedriver + 717422
# 15  chromedriver                        0x0000000104f8a439 chromedriver + 4834361
# 16  chromedriver                        0x0000000104f8f5dd chromedriver + 4855261
# 17  chromedriver                        0x0000000104f96572 chromedriver + 4883826
# 18  chromedriver                        0x0000000104f9030d chromedriver + 4858637
# 19  chromedriver                        0x0000000104f6216c chromedriver + 4669804
# 20  chromedriver                        0x0000000104faecd8 chromedriver + 4984024
# 21  chromedriver                        0x0000000104faee90 chromedriver + 4984464
# 22  chromedriver                        0x0000000104fbf87e chromedriver + 5052542
# 23  libsystem_pthread.dylib             0x00007ff8161551d3 _pthread_start + 125
# 24  libsystem_pthread.dylib             0x00007ff816150bd3 thread_start + 15

# %%
# 웹페이지 끝까지 스크롤하기.
last_height = driver.execute_script("return document.documentElement.scrollHeight")

while True:
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(1.5)

    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(1.5)

# %%
# #대댓글 버튼 누르기
# buttons = driver.find_element(By.CSS_SELECTOR,"#more-replies > a")
# buttons = driver.find_elements(By.CLASS_NAME,"yt-spec-touch-feedback-shape__fill")

# time.sleep(1.5)

# for button in buttons:
#     button.send_keys(Keys.ENTER)
#     time.sleep(1.5)
#     button.click()

# %%
html_source = driver.page_source
soup = BeautifulSoup(html_source, 'html.parser')

id_list = soup.select("div#header-author > h3 > #author-text > span")
comment_list = soup.select("yt-formatted-string#content-text")

id_final = []
comment_final = []

for i in range(len(comment_list)):
    temp_id = id_list[i].text
    temp_id = temp_id.replace('\n', '')
    temp_id = temp_id.replace('\t', '')
    temp_id = temp_id.replace('    ', '')
    id_final.append(temp_id) # 댓글 작성자

    temp_comment = comment_list[i].text
    temp_comment = temp_comment.replace('\n', '')
    temp_comment = temp_comment.replace('\t', '')
    temp_comment = temp_comment.replace('    ', '')
    comment_final.append(temp_comment) # 댓글 내용
    

pd_data = {"아이디" : id_final , "댓글 내용" : comment_final}
youtube_pd = pd.DataFrame(pd_data)

# youtube_pd.to_excel('result.xlsx')

# %%
youtube_pd
# Out:
#                     아이디                                              댓글 내용
# 0      @seonghojeon4250       저 당시 공연장에 있었던 사람들이 너무 부럽다.. 지금도 가슴 뭉클한 엔딩...
# 1             @travelho                  이 순간이 서태지 역사상 가장 감동적인 순간이 아닌가 싶다.
# 2              @fsutd11  마지막 박수 정말 소름돋네요팬들도 저런게 사라지는 서태지를 인정해주는. 존중해주는 ...
# 3      @user-yo6vu9dq8w  한국에 공연 잘하는 가수들 많지만이토록 극적이고 뭉클했던 엔딩은 여지껏본적이없다. ...
# 4      @user-id4vc3yi5c  와..진짜 지금 노래보다 훨씬 앞섰네 어떻게 20년 전에 대단하다 진짜! 이런 천재...
# ..                  ...                                                ...
# 115            @jim8271                                             최고다 대장
# 116    @user-mv5io3mk2p                                    아련하고 그때가 그립다...
# 117         @Kastro1999                                왜 어린시절이 그리워지는 건지 ..
# 118    @user-ly6jy4cc9v                                                 쩐다
# 119            @six3593         다시 들으니 ...눈물나~깊어가는 가을에 이게 모야..ㅜㅜ 잠들기 다 글렀군
#
# [120 rows x 2 columns]

# %%
driver.quit()
