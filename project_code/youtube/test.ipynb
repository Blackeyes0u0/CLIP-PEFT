# %%
class CustomImageDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None, target_transform=None):
        self.img_labels = pd.read_csv(annotations_file, names=['file_name', 'label'])
        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        image = read_image(img_path)
        label = self.img_labels.iloc[idx, 1]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
import pandas as pd
from torchvision import datasets
from torchvision import transforms
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np
import torch
import clip
from torch.utils.data import Dataset

class TextDataset(Dataset):
    def __init__(self, text_samples):
        self.text_samples = text_samples
        self.tokenizer = clip.tokenize
    def __len__(self):
        return len(self.text_samples)

    def __getitem__(self, i):
        return self.tokenizer(self.text_samples[i])
        #torch.Size([1, 77])

# based on https://gist.github.com/srikarplus/8bdb5bedf0ca25e894e39ea78fce2f39
def get_train_valid_loader(data_dir,
                           batch_size,
                           augment,
                           random_seed,
                           valid_size=0.1,
                           shuffle=True,
                           show_sample=False,
                           num_workers=4,
                           pin_memory=False):
    """
    
    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - augment: whether to apply the data augmentation scheme
      mentioned in the paper. Only applied on the train split.
    - random_seed: fix seed for reproducibility.
    - valid_size: percentage split of the training set used for
      the validation set. Should be a float in the range [0, 1].
    - shuffle: whether to shuffle the train/validation indices.
    - show_sample: plot 9x9 sample grid of the dataset.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.
    Returns
    -------
    - train_loader: training set iterator.
    - valid_loader: validation set iterator.
    """
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225],
    )

    # define transforms
    valid_transform = transforms.Compose([transforms.Resize((224,224)),
                                      transforms.ToTensor(),
                                      normalize])

    train_transform = transforms.Compose([transforms.Resize((224,224)),
                                      transforms.ToTensor(),
                                      normalize])
    
    # load the dataset
    train_dataset = datasets.ImageFolder(
        root=data_dir, transform=train_transform,
    ) 
    # output : torch.tensor
    valid_dataset = datasets.ImageFolder(
        root=data_dir, transform=valid_transform,
    )
    
    
    num_train = len(train_dataset) # 2303
    indices = list(range(num_train)) # [0~ 2302]
    split = int(np.floor(valid_size * num_train)) # number of split


    ######### TEXT ##########
    data = pd.read_csv('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/Youtube_thumbnails/metadata.csv')
    train_text_dataset=[]
    for i in range(num_train):
        img_dir =train_dataset.imgs[i][0].split('.jpg')[0].split('/')[-1]
        x_text = data[data['Id']==img_dir]['Title'].values[0]
        train_text_dataset.append(x_text)
        
    text_dataset = TextDataset(train_text_dataset)    
    ######### TEXT ##########
    
    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices) # shuffle list

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    img_train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler, # dataset 에서 train sampler를 통해서 나열된다.
        num_workers=num_workers, pin_memory=pin_memory,
    )
    
    text_train_loader = torch.utils.data.DataLoader(
        text_dataset, batch_size=batch_size, sampler=train_sampler, # dataset 에서 train sampler를 통해서 나열된다.
        num_workers=num_workers, pin_memory=pin_memory,
    )
    
    img_valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    text_valid_loader = torch.utils.data.DataLoader(
        text_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )


    # return (img_train_loader, img_valid_loader, train_dataset.class_to_idx)
    return (img_train_loader, img_valid_loader,text_train_loader, text_valid_loader,train_dataset.class_to_idx)
if __name__=='__main__':
    batch_size = 64
    PATH = '/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/'
    print(batch_size,PATH)
    
    img_train_loader, img_valid_loader,text_train_loader, text_valid_loader, class_idx = get_train_valid_loader(PATH, batch_size, False, 42, 0.1)
    # print(train_loader)
# Out:
# 64 /Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/

# %%
from torch.utils.data import TensorDataset
TensorDataset(train_text_dataset)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb 셀 3 line 2
#       <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X66sZmlsZQ%3D%3D?line=0'>1</a> from torch.utils.data import TensorDataset
# ----> <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X66sZmlsZQ%3D%3D?line=1'>2</a> TensorDataset(train_text_dataset)
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/dataset.py:189, in TensorDataset.__init__(self, *tensors)
#     188 def __init__(self, *tensors: Tensor) -> None:
# --> 189     assert all(tensors[0].size(0) == tensor.size(0) for tensor in tensors), "Size mismatch between tensors"
#     190     self.tensors = tensors
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/dataset.py:189, in <genexpr>(.0)
#     188 def __init__(self, *tensors: Tensor) -> None:
# --> 189     assert all(tensors[0].size(0) == tensor.size(0) for tensor in tensors), "Size mismatch between tensors"
#     190     self.tensors = tensors
#
# AttributeError: 'list' object has no attribute 'size'

# %%
data_dir =  '/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/'
normalize = transforms.Normalize(
    mean=[0.485, 0.456, 0.406],
    std=[0.229, 0.224, 0.225],
)

# define transforms
valid_transform = transforms.Compose([transforms.Resize((224,224)),
                                    transforms.ToTensor(),
                                    normalize])

train_transform = transforms.Compose([transforms.Resize((224,224)),
                                    transforms.ToTensor(),
                                    normalize])

# load the dataset
train_dataset = datasets.ImageFolder(
    root=data_dir, transform=train_transform,
) 
# output : torch.tensor
valid_dataset = datasets.ImageFolder(
    root=data_dir, transform=valid_transform,
)


num_train = len(train_dataset) # 2303

data = pd.read_csv('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/Youtube_thumbnails/metadata.csv')
train_text_dataset=[]
for i in range(num_train):
    img_dir =train_dataset.imgs[i][0].split('.jpg')[0].split('/')[-1]
    x_text = data[data['Id']==img_dir]['Title'].values[0]
    train_text_dataset.append(x_text)
    
text_dataset = TextDataset(train_text_dataset)    
######### TEXT ##########

# %%
train_dataset.loader
# Out:
# <function torchvision.datasets.folder.default_loader(path: str) -> Any>

# %%
torch.utils.data.ConcatDataset(train_dataset,text_dataset)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb 셀 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> torch.utils.data.ConcatDataset(train_dataset,text_dataset)
#
# TypeError: __init__() takes 2 positional arguments but 3 were given

# %%
for i in text_dataset:
    print(i.shape)
    ex1 = i
    break
ex1 = torch.randn(7,77)
ex2 = TensorDataset(ex1)

for ex in ex2:
    print(ex)
    
len(ex2)
# Out:
# torch.Size([1, 77])
# (tensor([-2.2151,  0.4487, -0.7209, -0.5288, -0.3134,  0.8301,  0.4111,  0.4607,
#          2.3378, -1.0587,  0.3869,  1.1700,  1.7866,  0.4223,  1.0794, -1.3185,
#          2.2825,  0.6776,  0.0247,  0.1273, -0.6101,  0.8246, -0.2096,  0.2768,
#         -0.9617,  0.5061,  1.4483, -0.8174, -1.9426, -0.8261,  0.2026, -2.1557,
#         -1.0443,  0.4542, -0.0118,  1.1586, -0.1939, -0.7520, -0.8866,  0.5831,
#          0.2581,  2.0732,  0.7419, -0.3048,  0.1289,  0.2774, -0.7035,  0.7765,
#         -0.8482,  0.6171,  0.1931, -0.5657, -0.5554,  0.5457,  1.2723, -1.2699,
#         -1.0902, -1.1580, -0.7242,  1.3460, -0.8266, -1.8129, -0.5953,  0.8787,
#         -0.0859,  1.5936, -0.0891,  0.0283, -0.5112, -1.1016,  0.3180, -0.8070,
#         -2.0656,  1.0838, -0.0907,  0.6057,  0.2351]),)
# (tensor([-1.2215, -0.4334,  0.6519,  1.2275, -0.1517, -0.0047, -0.4314,  0.5543,
#          0.2507, -2.5307,  1.1413,  0.6207,  1.0737,  0.3588,  1.4815, -1.8664,
#         -0.0345, -0.0497,  0.5464, -1.1275, -0.0850, -2.0554, -0.7029, -0.1543,
#          0.9553, -1.1092, -0.4921, -0.1370,  0.5858,  0.1776, -0.4955, -1.4797,
#          0.6465,  0.4381, -0.7899, -0.5514, -0.1065, -3.1097, -0.6447, -0.4443,
#         -0.8978,  0.6220,  0.1015, -0.6109, -0.4824, -0.0289,  2.0310,  0.9481,
#          0.0682, -2.6136,  0.4558,  1.0176,  1.6536,  0.4481,  0.3702,  0.1071,
#         -1.1820,  0.8326, -0.2640, -0.4590,  0.6442,  0.1892,  0.0191, -0.2510,
#         -1.6602, -0.4668, -0.4465, -1.3153, -1.7214,  0.0954, -0.3727, -1.6790,
#         -0.6576,  0.6450, -0.3776,  1.1113, -1.0422]),)
# (tensor([-0.1428, -0.4988,  1.1318,  0.2848,  1.3670,  1.3706,  0.6284, -0.8295,
#          0.2472, -0.3019,  1.3607, -0.2415,  0.8385,  0.8624,  1.0914,  1.8494,
#          0.8610,  2.0386, -2.8512,  2.2763,  1.1441, -1.7543, -0.4636, -0.6535,
#         -1.1158,  0.1563,  0.1570, -0.0481,  1.0725, -2.2695, -0.8691, -1.4021,
#         -1.8568,  0.2485, -1.9837, -0.7935,  0.6018, -0.6510, -0.7761, -1.1674,
#         -0.2806,  1.3616,  0.2262, -0.5036, -0.6731, -1.6255, -0.6297,  0.5635,
#          0.3438, -0.5468, -0.1595,  0.2440, -1.2399,  0.8931,  1.5702, -0.9195,
#         -0.9402,  0.3145, -0.7132,  2.0429, -0.2345, -0.4830, -1.2072,  0.2210,
#          0.1797,  2.0378, -0.0776, -0.9946,  0.0390,  1.7927,  0.2899,  0.4574,
#         -0.9685,  0.4283,  1.1640, -0.0710,  0.2518]),)
# (tensor([-0.8395, -0.5314,  0.6972,  1.6255, -0.2524, -1.6085,  0.6394, -0.0088,
#          1.7004,  0.4440, -1.6571, -0.4916,  0.1879, -1.4067,  0.7133,  0.1787,
#         -0.5739,  0.2693,  2.0758,  0.5865,  0.9108, -0.8005, -0.1662, -0.7534,
#          1.0165, -0.7668, -0.4394, -1.3010,  0.3638,  0.3876, -0.8569, -0.9776,
#         -0.4674,  0.8850, -1.5780,  0.2737,  0.2691,  0.3442, -1.5793,  0.7386,
#          1.2279,  0.0046,  1.1701, -1.0425, -1.7379, -0.9185,  1.6796,  1.5733,
#          2.4625, -1.2571,  1.2066,  0.2977,  0.1266,  1.1528, -0.4789,  1.6223,
#          0.3631,  0.5316, -0.4513, -0.7508,  0.2138, -1.5045, -1.2267, -0.4875,
#         -1.1871,  0.6970, -0.4939,  1.6981, -0.7135,  0.0142, -1.0881,  0.1508,
#         -1.1097, -0.7081, -0.1907,  0.1873, -0.1651]),)
# (tensor([ 0.2324, -0.0899, -0.3008, -0.1847,  0.1280, -1.4132,  2.5521,  1.2510,
#         -2.3207, -2.0026,  1.0756, -0.5971, -0.7518, -0.2374, -0.9869,  0.0955,
#          0.9629,  0.9146, -1.2560, -1.0274,  1.6022,  1.0319,  0.5237,  0.0356,
#         -2.2284,  0.0537,  1.1531, -0.1670,  1.2370,  0.1800, -0.4953, -0.6304,
#         -1.6039, -1.4021,  0.6001,  1.5408,  2.4149, -1.2445, -0.8630, -0.0579,
#          1.3608,  1.9636,  0.4491, -0.4422,  0.1211, -0.0311, -1.1709,  0.2825,
#         -0.0361,  0.4226, -1.8126, -0.3159,  1.0476,  0.9408, -0.3253, -0.2253,
#         -1.0097, -2.5225, -0.2096,  0.3881, -0.3378, -0.9136, -1.6691,  1.3425,
#         -0.5467,  0.0838,  0.5063, -1.3819, -0.6720,  0.7044, -0.5596, -0.9042,
#         -1.0811, -0.7380,  1.2424, -1.4982, -0.5352]),)
# (tensor([ 0.1580,  2.8293, -1.6871,  0.4519, -0.2884,  0.3582, -0.2785,  0.7590,
#         -0.5982,  0.7234,  1.0382, -0.4525,  0.2907,  0.2294, -0.3562,  0.6402,
#          1.1823, -2.3341, -2.5704,  2.2934, -0.2234, -0.7372,  0.3614, -0.6091,
#          0.0783,  0.6626,  0.1953,  0.2468,  0.0853,  2.3815, -0.3137,  0.3893,
#         -0.2717, -0.2502,  1.1299, -0.7467, -0.5051, -0.4490,  1.0985, -1.1982,
#          0.2988, -0.0540, -0.6693,  0.5838, -1.6377,  0.7032, -0.7434,  0.2946,
#         -0.3465, -0.0685, -1.6574,  0.8673, -0.2981, -0.3059, -2.5059, -0.0357,
#         -0.3383, -0.1879,  0.4204,  0.0980, -0.8674,  0.1092, -0.6445, -0.7833,
#          0.8242, -1.5364,  0.6051,  1.3471, -1.2939,  1.6522, -1.4478,  0.8065,
#         -0.6938, -0.5402, -0.8614, -0.6070, -2.4373]),)
# (tensor([ 0.9792, -0.3917,  0.3785,  2.2092, -1.5198,  0.0729,  1.4921,  1.5206,
#         -1.4731, -0.4417,  1.4630, -0.2115, -1.4740,  2.3196, -0.2204, -0.6473,
#         -0.8711, -1.1769,  1.9463,  0.8138,  0.5674, -0.4049,  0.5160,  0.0573,
#          1.1226,  0.2718,  3.4306,  0.8438,  0.9832,  0.0182, -0.9803, -0.4104,
#         -0.3544,  0.0358, -0.1336, -1.0555, -0.3409,  0.0175,  0.8392, -0.2956,
#          0.7767,  2.3002, -0.5637, -1.1247,  0.3922, -2.9780,  0.7782, -0.7264,
#         -0.7185,  1.1118,  1.6605,  0.1434,  0.4334,  0.6876, -0.5653,  1.2854,
#          0.1035, -0.3518, -1.0731, -0.4110, -1.8409,  0.5804,  0.5045, -0.1428,
#         -0.9396,  0.4610, -1.6491,  1.9270,  0.7015,  1.0742,  0.0583,  0.1986,
#          1.1718,  0.5296,  0.8717,  0.2226, -0.4333]),)
# 7

# %%
for i in text_dataset:
    print(i.shape)
    break
# Out:
# torch.Size([1, 77])

# %%
batch_size = 64
PATH = '/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/'
print(batch_size,PATH)

img_train_loader, img_valid_loader,text_train_loader, text_valid_loader, class_idx = get_train_valid_loader(PATH, batch_size, False, 42, 0.1)
# print(train_loader)
# Out:
# 64 /Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/

# %%
for i in text_dataset:
    print(i)
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb 셀 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X62sZmlsZQ%3D%3D?line=0'>1</a> for i in text_dataset:
#       <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X62sZmlsZQ%3D%3D?line=1'>2</a>     print(i)
#       <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X62sZmlsZQ%3D%3D?line=2'>3</a>     break
#
# NameError: name 'text_dataset' is not defined

# %%
text_train_loader
for i in train_dataset:
    print(i[0].shape)
    break
# Out:
# torch.Size([3, 224, 224])

# %%
for i in text_train_loader:
    print(i.shape)
    break
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'TextDataset' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'TextDataset' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'TextDataset' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'TextDataset' on <module '__main__' (built-in)>
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fe1e175d4c0>
# Traceback (most recent call last):
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1466, in __del__
#     self._shutdown_workers()
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1424, in _shutdown_workers
#     if self._persistent_workers or self._workers_status[worker_id]:
# AttributeError: '_MultiProcessingDataLoaderIter' object has no attribute '_workers_status'
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# _pickle.UnpicklingError: pickle data was truncated
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1120, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1119 try:
# -> 1120     data = self._data_queue.get(timeout=timeout)
#    1121     return (True, data)
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/queues.py:107, in Queue.get(self, block, timeout)
#     106 timeout = deadline - time.monotonic()
# --> 107 if not self._poll(timeout):
#     108     raise Empty
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/connection.py:424, in Connection._poll(self, timeout)
#     423 def _poll(self, timeout):
# --> 424     r = wait([self], timeout)
#     425     return bool(r)
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/connection.py:931, in wait(object_list, timeout)
#     930 while True:
# --> 931     ready = selector.select(timeout)
#     932     if ready:
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/_utils/signal_handling.py:66, in _set_SIGCHLD_handler.<locals>.handler(signum, frame)
#      63 def handler(signum, frame):
#      64     # This following call uses `waitid` with WNOHANG from C side. Therefore,
#      65     # Python can still get and update the process status successfully.
# ---> 66     _error_if_any_worker_fails()
#      67     if previous_handler is not None:
#
# RuntimeError: DataLoader worker (pid 72008) exited unexpectedly with exit code 1. Details are lost due to multiprocessing. Rerunning with num_workers=0 may give better error trace.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb 셀 3 line 1
# ----> <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X52sZmlsZQ%3D%3D?line=0'>1</a> for i in text_train_loader:
#       <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X52sZmlsZQ%3D%3D?line=1'>2</a>     print(i.shape)
#       <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X52sZmlsZQ%3D%3D?line=2'>3</a>     break
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1316, in _MultiProcessingDataLoaderIter._next_data(self)
#    1313     return self._process_data(data)
#    1315 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1316 idx, data = self._get_data()
#    1317 self._tasks_outstanding -= 1
#    1318 if self._dataset_kind == _DatasetKind.Iterable:
#    1319     # Check for _IterableDatasetStopIteration
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1282, in _MultiProcessingDataLoaderIter._get_data(self)
#    1278     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1279     # need to call `.task_done()` because we don't use `.join()`.
#    1280 else:
#    1281     while True:
# -> 1282         success, data = self._try_get_data()
#    1283         if success:
#    1284             return data
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1133, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1131 if len(failed_workers) > 0:
#    1132     pids_str = ', '.join(str(w.pid) for w in failed_workers)
# -> 1133     raise RuntimeError('DataLoader worker (pid(s) {}) exited unexpectedly'.format(pids_str)) from e
#    1134 if isinstance(e, queue.Empty):
#    1135     return (False, None)
#
# RuntimeError: DataLoader worker (pid(s) 72008) exited unexpectedly

# %%
torch.tensor('hello')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb 셀 3 line 1
# ----> <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> torch.tensor('hello')
#
# TypeError: new(): invalid data type 'str'

# %%
for i in text_train_loader:
    print(i)
    break
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'TextDataset' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'TextDataset' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'TextDataset' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'TextDataset' on <module '__main__' (built-in)>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1120, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1119 try:
# -> 1120     data = self._data_queue.get(timeout=timeout)
#    1121     return (True, data)
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/queues.py:107, in Queue.get(self, block, timeout)
#     106 timeout = deadline - time.monotonic()
# --> 107 if not self._poll(timeout):
#     108     raise Empty
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/connection.py:424, in Connection._poll(self, timeout)
#     423 def _poll(self, timeout):
# --> 424     r = wait([self], timeout)
#     425     return bool(r)
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/multiprocessing/connection.py:931, in wait(object_list, timeout)
#     930 while True:
# --> 931     ready = selector.select(timeout)
#     932     if ready:
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/_utils/signal_handling.py:66, in _set_SIGCHLD_handler.<locals>.handler(signum, frame)
#      63 def handler(signum, frame):
#      64     # This following call uses `waitid` with WNOHANG from C side. Therefore,
#      65     # Python can still get and update the process status successfully.
# ---> 66     _error_if_any_worker_fails()
#      67     if previous_handler is not None:
#
# RuntimeError: DataLoader worker (pid 71465) exited unexpectedly with exit code 1. Details are lost due to multiprocessing. Rerunning with num_workers=0 may give better error trace.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb 셀 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> for i in text_train_loader:
#       <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X51sZmlsZQ%3D%3D?line=1'>2</a>     print(i)
#       <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X51sZmlsZQ%3D%3D?line=2'>3</a>     break
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1316, in _MultiProcessingDataLoaderIter._next_data(self)
#    1313     return self._process_data(data)
#    1315 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1316 idx, data = self._get_data()
#    1317 self._tasks_outstanding -= 1
#    1318 if self._dataset_kind == _DatasetKind.Iterable:
#    1319     # Check for _IterableDatasetStopIteration
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1282, in _MultiProcessingDataLoaderIter._get_data(self)
#    1278     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1279     # need to call `.task_done()` because we don't use `.join()`.
#    1280 else:
#    1281     while True:
# -> 1282         success, data = self._try_get_data()
#    1283         if success:
#    1284             return data
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1133, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1131 if len(failed_workers) > 0:
#    1132     pids_str = ', '.join(str(w.pid) for w in failed_workers)
# -> 1133     raise RuntimeError('DataLoader worker (pid(s) {}) exited unexpectedly'.format(pids_str)) from e
#    1134 if isinstance(e, queue.Empty):
#    1135     return (False, None)
#
# RuntimeError: DataLoader worker (pid(s) 71465, 71467) exited unexpectedly

# %%
train_text_dataset = 
for i in range(num_train-split-1):
    img_dir = train_dataset.imgs[train_idx[i]][0].split('.jpg')[0].split('/')[-1]
    x_text = data[data['Id']==img_dir]['Title'].values[0]



for i in range(split-1):
    pass

img_dir,x_text
# Out:
# ('SkY1DiyCqTU', 'How Expensive is it to Travel Japan? | Budget Travel Tips')

# %%
# train_dataset.imgs
indices = list(range(20))
np.random.shuffle(indices)
print(indices)
# Out:
# [1, 14, 11, 6, 5, 19, 8, 16, 17, 9, 15, 13, 3, 4, 18, 7, 2, 12, 0, 10]

# %%
batch_size = 64
PATH = '/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/'
print(batch_size,PATH)

train_loader, test_loader, class_idx = get_train_valid_loader(PATH, batch_size, False, 42, 0.1)
# print(train_loader)
# Out:
# 64 /Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/

# %%
normalize = transforms.Normalize(
    mean=[0.485, 0.456, 0.406],
    std=[0.229, 0.224, 0.225],
)

train_transform = transforms.Compose([transforms.Resize((224,224)),
                                    transforms.ToTensor(),
                                    normalize])
train_dataset = datasets.ImageFolder(
    root=PATH, transform=train_transform,
)

# %%
train_dataset.imgs
# Out:
# [('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/3d6DsjIBzJ4.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/CfW845LNObM.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/EK32jo7i5LQ.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/GNcFjFmqEc8.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/HEfHFsfGXjs.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/IHZwWFHWa-w.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/Ilg3gGewQ5U.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/Kas0tIxDvrg.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/M64HUIJFTZM.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/OkmNXy7er84.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/PFDu9oVAE-g.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/QJYmyhnaaek.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/WUvTyaaNkzM.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/XFDM1ip5HdU.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/aircAruvnKk.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/bBC-nXj3Ng4.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/d-o3eB9sfls.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/d4EgbgTm0Bg.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/fNk_zzaMoSs.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/gB9n2gHsHN4.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/gxAaO2rsdIs.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/jsYwFizhncE.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/k7RM-ot2NWY.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/kYB8IZa5AuE.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/p_di4Zn4wz4.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/r6sGWTCMz2k.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/rB83DpBJQsE.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/sD0NjbwqlYw.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/spUNpyF58BY.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/3Blue1Brown/zwAD6dRSVyI.jpg',
#   0),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/-9JQndAAvLE.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/-VRx0GRo-Ws.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/0viKv1RDhak.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/2Sj2fd6b_Cg.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/8NLE8d4GW-Y.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/9ANWQPD4Ak0.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/HLedllETYD4.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/IF59QNrF1VQ.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/LiEFyZGcK5c.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/LqUxOfIdxxo.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/PIotJjzDyHM.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/QgONIEV7Rh0.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/VqP-2ftKIYI.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/XAtzfJcuHjY.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/YiEj9mrqTN0.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/YiM9oosSvNg.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/ZLuxpDxhHYA.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/Zn0GBm1ltIk.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/ce28TIoa4ao.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/eoFgUT82pTc.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/fA5Z2e86Hns.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/fxk3ZTusSqI.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/goxvS5pxLDo.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/iVv_xiIx22Q.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/ii50SWTJSoA.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/nbBHdhFs1q0.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/p6OkpHNtvE4.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/A&E/s4X-CSFTUfo.jpg',
#   1),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/-gal8E_dgE8.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/0U_Mpg59FSw.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/29ZP8ADQJ1Y.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/39opX6-QJJI.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/48DD3kekP3E.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/4G6Y6glM_hg.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/AAtoia2BbjE.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/Bhos_P4a-JQ.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/CmI2dXo14sY.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/F3RGIBExjfE.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/IsGWMxZhlOY.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/LHx63zUMLpM.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/PlI3gjkcPz0.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/UT9a7EtxQOM.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/Uk3-FxTF-BU.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/eHSvv8eSsvc.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/h5st8mluVUo.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/iCd5Po4fPb0.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/nUSI5uUocho.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/pJbC7W2fMvQ.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/rA1Kjvxu28w.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/rRSOt9SpBMI.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/uJa584PPm-E.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/uxhgrd6HWVw.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/whJgPudKgE0.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/wkPxBltQzzg.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/About To Eat/xlPJfeNzBzE.jpg',
#   2),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/-tBy2jemw4s.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/0GCuvcTI090.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/3LS83dDqoGU.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/5VDnj8IEWNc.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/5VmCvChcGzU.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/AHuj4DCueO4.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/HEaaln5jDl8.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/IXgX_r-x-XE.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/M400lV0GNV4.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/RuAQo97K-zE.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/SkY1DiyCqTU.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/TwPHIABVdg8.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/U7Q3sKNuZA0.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/_IOZbJ7PCPk.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/aVT0BvWZcLg.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/faJM9iQZMbQ.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/fmOP68S5v7c.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/fso4yjbgceY.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/icwENiwT1zI.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/j5gy6QLq8wg.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/l3ifRE7BQiM.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/mtnVU4BU39E.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/nfpWAqK0YZE.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/qKFep4ekvx0.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/tLExSqNNMPc.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/tORfGTrr1ww.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/u240yK8_fVM.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/ueTa3dytTuY.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/wwH3rA8Evow.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Abroad in Japan/yWwfNmIIc_Q.jpg',
#   3),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/-naamtpQ8lw.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/0SmVHslppDQ.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/0Xi2rurVAvs.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/16q8_32M03k.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/4hCy4-G37jA.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/5NX-U36VDis.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/5pP8TLwO_Ks.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/6ghOAKzQMGY.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/7Fjn4GRw8qE.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/E9-x3jRSQvQ.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/FcX0pkXSKl4.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/G_ZxvxtUwus.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/HtJa9jJdzac.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/KM0ZV1X9o7o.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/KrMvtS7DAlM.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/N1uHX_WQsEY.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/ObQhpDQzfXE.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/PGqZkOveLb8.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/Q1UXZs-yWDc.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/SzkHeDPTLOg.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/TjP0UgI8CTg.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/VmzQ2hdfQcs.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/X3XkG6GL_DM.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/Y80ZTbjtz5c.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/_RKYQdUUttc.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/r-7UBVzjO8Y.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/s_Sf4wfwvzI.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Austin Evans/tXqQs7oMwmg.jpg',
#   4),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BBC News/6VixqvOcK8E.jpg',
#   5),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BBC News/DDo4CA13LbY.jpg',
#   5),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BBC News/JqhCAORmsaE.jpg',
#   5),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BBC News/LKXvdyNz6L8.jpg',
#   5),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BBC News/RwTAgom_VX8.jpg',
#   5),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BBC News/t17O2AKa2FU.jpg',
#   5),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/1R97tphpD_M.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/1VZkiQUzITU.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/1ci3l7pnfdk.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/6PtiY-ev2qA.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/7vQyrlW8ahw.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/9na8UBoncy4.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/CwwZFxH1W4c.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/DBkONFkdWSM.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/GpMP6Nh3FvU.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/HnE60IVm51E.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/KQMZexRllNs.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/NCPNTsKBZS0.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/NMDZcbkgpJA.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/OA6F6liLnvc.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/XfcvX0P1b5g.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/_28b0P_6VvY.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/_Kav2K1DVWo.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/_OzpODjTISc.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/eS_rEzKdzBA.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/fMWnaR5uJxQ.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/k_B3a2cCqo0.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/pl20NdwAs3k.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/q-1HikE4b54.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/q9XmXad_wmo.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/snWvNkJCCs8.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/tF0dCNxfYHk.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/vboQOQwifwg.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Barely Sociable/xEeyLDTAkK8.jpg',
#   6),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/-pAOuR8s03Q.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/1Gdl-A1DvpA.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/2J6bJnwr1rw.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/4nqJiBRNQuw.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/BriBDiBxaMY.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/Ew-3-8itpjc.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/H2nY7Tu1Qgs.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/HzUIUTatyZI.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/IeM8OReKzfQ.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/J3xLG-whfFk.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/Jpd_CUX2o98.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/LrRzZXuE9qA.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/RrkL9e2w7gQ.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/SGNwG_MjslI.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/TudhYwBrgYg.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/UPS4nxI0b9g.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/VyaxDWLe6A4.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/WrOzwoMKzH4.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/XY-hOqcPGCY.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/_r9Ndb6N_y0.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/fEMxFSjmo5Q.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/fuOnYDEIjUA.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/g1GFJxVeH9c.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/hc3TEaT3WHA.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/oidnwPIeqsI.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/ppi0khS0s_8.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/qOsp6IMqnn0.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/qWAagS_MANg.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/u6TFP_r2oA8.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Bon Appétit/xmRaWhae5e8.jpg',
#   7),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/-378LN_fUqE.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/-6Up7CG5d6M.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/529h0a2RMt4.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/5WL8Omm7b-4.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/6Ock5HVWPlk.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/7XoGwFNUwiM.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/8pD7MXQfdqU.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/Cr8N3xwvonY.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/Cvo1sjervSU.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/HhrbbYD5ScI.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/HlBYdiXdUa8.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/I6Oku6zex-k.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/NHQKH-nc8JY.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/Nb7WLJrW_PU.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/O9gg0pz7rlc.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/RKpvSSzdRCg.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/S5HHOjOmWag.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/SQUNZTdwGoc.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/TPLnnSHSeLE.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/Uhhw6Jw295o.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/X-Wmy_L5o9w.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/cn1kw3_mI70.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/fVt1fWsM73k.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/nS7xHq3LNfU.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/nb-xbTV-22A.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/ppxNZX4MDd8.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/rRgQ067tyNg.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/sxpxDdLFSBo.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/yPr9Xb_oRXk.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Brooklyn Nine-Nine/ygPBddnvhwY.jpg',
#   8),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/-XbX4eQlwgs.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/2GZrPR5Ajrs.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/3tvegr-O9vI.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/43uTBB574g4.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/6R8n6FbXVc8.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/7fgCfC3bM0U.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/A1LUHmUcIsk.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/G4Sn91t1V4g.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/GTXP2FzQS94.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/HuEREfPjT5Y.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/L3MtFGWRXAA.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/L6EwZWWRA-U.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/M6XiFKB7j0w.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/NHiqsrYkcuk.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/QtVL76gh09U.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/RYuipbRGu5s.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/V4Uuxg6jmbo.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/VzHtsoBwBqI.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/Z5FoX3ju2J0.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/b81Cr97ANrk.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/bcdJgjNDsto.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/ct-CdyT4HkM.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/iN8zmmCRqUA.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/n4bucphC9r4.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/pWUzkxtoJ2I.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/slmYnJdDQ1U.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/vzSfnduxNDg.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/BuzzFeedVideo/wduZHtRbSkY.jpg',
#   9),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/AiwOQRhKF1E.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/BDPCrGjAKXk.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/Baa_Db8RfxM.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/C0UyT5y6DHQ.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/C2EfChhlEYo.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/GIdzIBDNt2s.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/Gj5lJWy0TYk.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/JUBSQXmm-3k.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/KSiZrKvHlVQ.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/MCMY2kMVPa4.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/MOuV-0f66Y4.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/Ook-J58HnvM.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/Rd8PFcqUxA4.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/TZt6GDXP2OQ.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/TtzAcNZYflc.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/UFyIMBlFyos.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/UYsaY4ga4aU.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/XpMhtAqOPKA.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/ZxKqoIOiW7s.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/elKXLQTOc-s.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/giNAjqgCAaA.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/iEjvVcdCDB4.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/leDLtQHFzKE.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/obng-x8oAk4.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/pPyfwf-Vw0A.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/q8f4uxCGWJA.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/tV8OhAc3Zyc.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/wRccvEsIybA.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/xkiSfeGtYw4.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CDawgVA/xosZKMYZ5JY.jpg',
#   10),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/-nSHiHO6QJI.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/0lrIqGphJx8.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/3KPYIaks1UY.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/464puoD09dM.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/7S0EshM9lM4.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/CEHMfdqwWXA.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/CLUWDLKAF1M.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/EgI_KAkSyCw.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/EwAkH19MB-I.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/KHSdObeUdxI.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/Q0o3Ci71W6U.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/QP_9rFbvY_Q.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/RmAYo5E52sI.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/Sep0Otx4qO4.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/TX1sRxCrduA.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/U1wEO-pHizQ.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/UMdI5JwoI2I.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/VYLJLxKBhSU.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/Vr6XYTeivPs.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/a2A5Ld-QWnU.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/b-VCzLiyFxc.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/gElfIo6uw4g.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/ip7gRmrN8TA.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/lA77zsJ31nA.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/tLcnJEMnlTs.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/tccTiVeQKA4.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/CNET/udwPo6vLfSU.jpg',
#   11),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/-NPmBkYb_mY.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/5LI2nYhGhYM.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/63qn9w-a2ok.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/9vncG0IP9qU.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/Cw7g8ixbomU.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/F-xa6Rk5rzg.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/HoyMs7XXSbw.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/Hy6vddbQa8Q.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/KbgvSi35n6o.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/LuM1IXl66B8.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/NXCtgI2lkFw.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/Op8KgCcoqn8.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/PI4EszMsYy4.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/S_doxRtYd8o.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/U5EDORs8Jkk.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/W8sGTh7ZpoY.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/Xmrn2IuSW-Q.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/YGgUrj10HdM.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/_dSp_f0f9gE.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/aO3JgPUJ6iQ.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/eKFrZNXB29M.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/eLAwG7CjF_k.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/em-pVICrnqM.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/iLIAMt0wXzQ.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/ou7KSmfC3lA.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/rsXQInxxzBU.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/sWy1qmMoToM.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/uuhkVTJ6A_c.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/vECmNK0xHNk.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Captain Disillusion/zhPRtCW5sRk.jpg',
#   12),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/4x04M8YwOBw.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/610rMnK9HCo.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/6Lj_gFyI1Qs.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/EwmDdMzzDjY.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/GvzKAnzWTrw.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/I1AeAY8nn_s.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/KTeXDOC_fRg.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/Lgy0_uB3sLI.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/Lv4yoQKJ12s.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/NvaoIoULjrM.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/RiTf1SOKa1s.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/Wk-isKUjWBQ.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/XKH5Gd92k74.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/Xz2z1LXbxzE.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/YlYoAiMKGC4.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/_BL1y6v974Y.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/d_k0f8VGxtw.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/kNZV3Bry5UU.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/kaQzEvpmDIo.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/lIXl8eSzsFA.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/nhQPBSa2w9k.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/nrB3HqVbB3o.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/p0-ldVORQyE.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/rlK7JIAz9WY.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/tP7VdxVY6UQ.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Car Throttle/u3XSfVPFM74.jpg',
#   13),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/2nYF46P7B2c.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/3aQRO29ZzbE.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/7VX090Fi63E.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/8Vj9avZxuwI.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/AmEEYTtIfMU.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/Bb5VfiFy0kY.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/Bbi0kEaTgio.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/CFXfSBR5Q9w.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/LfR4QfmwTAc.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/PNhuDCVIydw.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/PRSoRkM8GcM.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/Pctzq_pT2MU.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/QcWELyTbdP4.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/QjuWqBzO7qY.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/Quvby2Me5CM.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/UEJbKLZ7RmM.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/XUhXLsrZiE0.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/Z5x22ef7A-w.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/axI5Luw0Eos.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/iI1o2hNy2hE.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/n4vusY2-rkQ.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/o690DovjDAc.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/rXHTXdlWw1w.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/s--5ft5YiHg.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/sStxk4mv_DY.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/u-TNsO33eqQ.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/u6UeJXkzDW8.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/vUdSUDObwVc.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/ChrisFix/w0EmwhiTD74.jpg',
#   14),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Coder Coder/45eWEO0gRHI.jpg',
#   15),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Coder Coder/8w_kHIAkucA.jpg',
#   15),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Coder Coder/9qkzDLos7fk.jpg',
#   15),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Coder Coder/CdDXbvBFXLY.jpg',
#   15),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Coder Coder/FLcRb289uEM.jpg',
#   15),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Coder Coder/FboXxLxg8eo.jpg',
#   15),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Coder Coder/GVTRJa4B4fY.jpg',
#   15),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Coder Coder/GnD7IQ48IQE.jpg',
#   15),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Coder Coder/LQsjNmkqUOc.jpg',
#   15),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Coder Coder/OdkzB13xjL0.jpg',
#   15),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Coder Coder/P3aKRdUyr0s.jpg',
#   15),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Coder Coder/UQGoVB_zMYQ.jpg',
#   15),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Coder Coder/XKehq1w4vfg.jpg',
#   15),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Coder Coder/aydFCQiUW44.jpg',
#   15),
# ...
#   33),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/-wmfpoq_Y0E.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/1ZgxeX2dCnQ.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/2rRIqrWuYy4.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/3aZuj_SDqDo.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/9NKG9lR34dM.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/9XN57BhyZwk.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/GmULc5VANsw.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/HiTqIyx6tBU.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/HsLup7yy-6I.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/MQEEJ57Gsow.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/O5BJVO3PDeQ.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/P1FUMdHU29c.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/QWhUvm8SunY.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/Qh9KBwqGxTI.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/QynNpzqYt0Y.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/ROaj3bCpZEM.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/SvjwXhCNZcU.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/UBPg5ftCMv8.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/Y7nymZEXjf8.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/YcuofODMCMU.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/_p4h3jwJob0.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/fp2EZbbuMa0.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/h-StyszRCzc.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/kjyeCdd-dl8.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/nzFykQv6Q08.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/t95aLo7R1NM.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/vZlmUG00OrI.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/vvXRcwcIJh4.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Internet Historian/vw9zyxm860Q.jpg',
#   34),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JCS - Criminal Psychology/1J2YOLQM2Yc.jpg',
#   35),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JCS - Criminal Psychology/9x2NaGkl6BI.jpg',
#   35),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JCS - Criminal Psychology/BemHqUqcpI8.jpg',
#   35),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JCS - Criminal Psychology/L0H6xYwMQnk.jpg',
#   35),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JCS - Criminal Psychology/Mwt35SEeR9w.jpg',
#   35),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JCS - Criminal Psychology/UQt46gvYO40.jpg',
#   35),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JCS - Criminal Psychology/WLSNPkf8RCU.jpg',
#   35),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JCS - Criminal Psychology/Xfg861hO-Ag.jpg',
#   35),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JCS - Criminal Psychology/eJt_afGN3IQ.jpg',
#   35),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JCS - Criminal Psychology/nVZhV7M3mNE.jpg',
#   35),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JCS - Criminal Psychology/sVF_SlzxBJ4.jpg',
#   35),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JCS - Criminal Psychology/sv0iN5J-9mk.jpg',
#   35),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JCS - Criminal Psychology/yS3k_Inm45Q.jpg',
#   35),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/-xfra2_tVF8.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/0sr1Xeocuuc.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/7mmlmxamw_k.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/8kJacGNg_9w.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/9ugC3TXSKoE.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/CO5E-VoR3sA.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/Cn1MugPalaA.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/FozCkl1xj-w.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/Ni5tgO4Bh3Y.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/UA3jI71gy8E.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/VFns39RXPrU.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/XolBNaavdAQ.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/cZFhjMQrVts.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/dAfdPFWiF9U.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/eWISIF0k8Mc.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/kJcpTSNWXdQ.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/mwahLAUzf1s.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/JRE Clips/tqqiZdqBNI0.jpg',
#   36),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/-UdWguw90g4.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/0KmUoTfGa34.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/0oBi8OmjLIg.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/1fPWr0d5zBE.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/4FMdbwDdHlw.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/Ck0ozfJV9-g.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/EiKK04Ht8QI.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/HTXTVfBCeSY.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/Hv6EMd8dlQk.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/K7s1IYVfvSA.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/M5v1nXiUaOI.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/OTfp2_SwxHk.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/Pb3AAfz5Yjg.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/Rgx8dpiPwpA.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/TLysAkFM4cA.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/X34ZmkeZDos.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/fB7nyxXaczY.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/gvAF9mboxFM.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/hWFDujYzvbI.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/kZC12U6EhTc.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/lpcpsCY4Mco.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/pKO9UjSeLew.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/pvimAM_SLic.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/sW9npZVpiMI.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/uHt01D6rOLI.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/uxRf7KS3abo.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/vT3GUKuAzIs.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma Tech/xC-c7E5PK0Y.jpg',
#   37),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma in NYC/015wj1C5wK0.jpg',
#   38),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma in NYC/3kJPxsELVAk.jpg',
#   38),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma in NYC/C0f2pu0EVSg.jpg',
#   38),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma in NYC/MGGhz29kYYA.jpg',
#   38),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma in NYC/VnIsuYVlSls.jpg',
#   38),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma in NYC/WTxTBFU7Sdk.jpg',
#   38),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma in NYC/bdUVehx6UBU.jpg',
#   38),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma in NYC/gtXpRZUAc1o.jpg',
#   38),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma in NYC/l0IefQRFVfE.jpg',
#   38),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma in NYC/pF2mNC4EXfA.jpg',
#   38),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma in NYC/pYy5-KowMj0.jpg',
#   38),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Joma in NYC/qNxQRgsF2NA.jpg',
#   38),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/-qv7k2_lc0M.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/07mBfR8erMY.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/0z-oJTZ1b5Q.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/3-jv7doUI8o.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/5Kod1q39ddE.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/5pKt4gaErvU.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/7uG9PGqaWeo.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/9-GRzu6zbS0.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/IHfiMoJUDVQ.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/IkTZ8BVAlFE.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/NQNAdgo91JE.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/SxwMTAy1gP0.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/TLnUJzueBOQ.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/UCW_UH-k-ec.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/WqBZVlgORbY.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/YrpoK7Askck.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/ZgyU0LyWZ9M.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/__d2FMCtgi4.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/_uScCrpAW4U.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/bxHEZU0AFcQ.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/ir_OzWzbnC0.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/izh-j8KUYjs.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/j-2ZxldMO-M.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/leL_bsHEZdM.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/nlD9JYP8u5E.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/ntfProwNYkE.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/rxhKrtb3XsE.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/vBzPsY3D58k.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/vNIe_UwHPU0.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Key & Peele/ztRSm_SJP58.jpg',
#   39),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Kurzgesagt – In a Nutshell/1-NxodiGPCU.jpg',
#   40),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Kurzgesagt – In a Nutshell/1AElONvi9WQ.jpg',
#   40),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Kurzgesagt – In a Nutshell/3mnSDifDSxQ.jpg',
#   40),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Kurzgesagt – In a Nutshell/4_aOIA-vyBo.jpg',
#   40),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Kurzgesagt – In a Nutshell/5iPH-br_eJQ.jpg',
#   40),
#  ('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/thumbnails/images/Kurzgesagt – In a Nutshell/7_e0CA_nhaE.jpg',
#   40),
#  ...]

# %%
from PIL import Image

counts = 0
for i in train_dataset:
    # print(i[0].shape)
    # print(i[1])
    # image = i[0].permute(1, 2, 0).numpy()
    counts+=1
# Show the image
print(counts)
# plt.imshow(image)
# Out:
# 2303

# %%
num_train = 100
indices = list(range(num_train))
split = int(np.floor(0.1 * num_train)) # np.floor : 소수점이하 버림.

if True:
    np.random.seed(77)
    np.random.shuffle(indices)

train_idx, valid_idx = indices[split:], indices[:split]
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
import matplotlib.pyplot as plt

for i in train_loader:
    print(i[0].shape,i[1])
    break

x = i[0].numpy().reshape((64,224,224,3))
x = i[0].permute(0, 2, 3, 1).cpu().numpy()

plt.imshow(x[22])
# Out:
# /Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'dlopen(/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c106detail19maybe_wrap_dim_slowIxEET_S2_S2_b
#   Referenced from: <870081F6-12FD-3CEA-BC5C-30F4764F2A98> /Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torchvision/image.so
#   Expected in:     <F2FE5CF8-5B5B-3FAD-ADF8-C77D90F49FC9> /Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/lib/libc10.dylib'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# /Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'dlopen(/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c106detail19maybe_wrap_dim_slowIxEET_S2_S2_b
#   Referenced from: <870081F6-12FD-3CEA-BC5C-30F4764F2A98> /Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torchvision/image.so
#   Expected in:     <F2FE5CF8-5B5B-3FAD-ADF8-C77D90F49FC9> /Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/lib/libc10.dylib'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# /Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'dlopen(/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c106detail19maybe_wrap_dim_slowIxEET_S2_S2_b
#   Referenced from: <870081F6-12FD-3CEA-BC5C-30F4764F2A98> /Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torchvision/image.so
#   Expected in:     <F2FE5CF8-5B5B-3FAD-ADF8-C77D90F49FC9> /Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/lib/libc10.dylib'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# /Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'dlopen(/Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c106detail19maybe_wrap_dim_slowIxEET_S2_S2_b
#   Referenced from: <870081F6-12FD-3CEA-BC5C-30F4764F2A98> /Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torchvision/image.so
#   Expected in:     <F2FE5CF8-5B5B-3FAD-ADF8-C77D90F49FC9> /Users/juniverse/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/lib/libc10.dylib'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# torch.Size([64, 3, 224, 224]) tensor([42, 41, 31, 33, 68, 23, 13, 26, 40, 29, 18, 36, 50, 14, 80, 31, 34, 34,
#         11, 45, 61, 14, 21, 37,  1, 27, 66, 10, 47, 54, 31, 74,  6, 84, 41, 25,
#         60, 63, 85, 88, 23, 42, 48, 71, 79, 72, 16, 71,  4, 12,  4, 37, 81, 55,
#         78, 77, 10, 54, 64, 75, 29, 18, 15, 61])

# %% [markdown]
# ## bert based tokenizer

# %%
#!g1.1
import pandas as pd
import numpy as np
import torch, transformers, time, datetime, random

from transformers import BertTokenizer, BertForSequenceClassification, AdamW, BertConfig, get_linear_schedule_with_warmup
from torch.utils.data import TensorDataset, random_split, DataLoader, RandomSampler, SequentialSampler
#!g1.1
print('Loading BERT tokenizer...')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

tokenizer
# Out:
# Loading BERT tokenizer...
# BertTokenizer(name_or_path='bert-base-uncased', vocab_size=30522, model_max_length=512, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True)

# %%
data = pd.read_csv('/Users/juniverse/Desktop/pointcloud/VectorUniverse/Data/Youtube_thumbnails/metadata.csv')

cat_map = {}
cat_list = data["Category"].unique().tolist()
for i in range(len(cat_list)):
    cat_map[cat_list[i]] = i


# cat_map : index of category 
# cat_list : list of category 


data["cat_code"] = data["Category"].apply(lambda x: cat_map[x])


X = data.Title.apply(lambda x: ''.join([i for i in x if not i.isdigit()])).tolist()
y = data.cat_code.tolist()

encoded_dict = tokenizer(
                    X,
                    add_special_tokens=True,
                    max_length=64,
                    truncation=True,
                    padding=True,
                    return_tensors='pt'
               )

input_ids = [encoded_dict['input_ids']]
attention_masks = [encoded_dict['attention_mask']]

input_ids = torch.cat(input_ids, dim=0)
attention_masks = torch.cat(attention_masks, dim=0)
labels = torch.tensor(y)

# %%
encoded_dict['input_ids'].shape,encoded_dict['token_type_ids'].shape,encoded_dict['attention_mask'].shape
# Out:
# (torch.Size([2515, 29]), torch.Size([2515, 29]), torch.Size([2515, 29]))

# %%
input_ids.size(), attention_masks.size(), labels.size()
# Out:
# (torch.Size([2515, 29]), torch.Size([2515, 29]), torch.Size([2515]))

# %%
dataset = TensorDataset(input_ids, attention_masks, labels)

train_size = int(0.8 * len(dataset)) # 0.67
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

print('{:>5,} training samples'.format(train_size))
print('{:>5,} validation samples'.format(val_size))
# Out:
# 2,012 training samples
#   503 validation samples

# %%
batch_size = 64 # 4 - 32

train_dataloader = DataLoader(
            train_dataset,
            sampler = RandomSampler(train_dataset),
            batch_size = batch_size
        )

validation_dataloader = DataLoader(
            val_dataset,
            sampler = SequentialSampler(val_dataset),
            batch_size = batch_size
        )

# %%
for i in train_dataloader:
    print(i[0].shape,i[1].shape,i[2].shape)
    break
# Out:
# torch.Size([64, 29]) torch.Size([64, 29]) torch.Size([64])

# %%
#!g1.1

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased",
    num_labels = len(cat_list),
    output_attentions = False,
    output_hidden_states = False
)

model.to(device)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=22, bias=True)
# )

# %%
optimizer = AdamW(model.parameters(),
                  lr = 2e-5, # default is 5e-5
                  eps = 1e-8 # default is 1e-8.
                )


epochs = 5 # 2 - 4

total_steps = len(train_dataloader) * epochs

scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0,
                                            num_training_steps = total_steps)

def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))


seed_val = 42

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

total_t0 = time.time()

for epoch_i in range(0, epochs):
    print(f'\n======== Epoch {epoch_i + 1} / {epochs} ========')
    print('Training...')

    t0 = time.time()
    
    total_train_loss = 0

    model.train()

    for step, batch in enumerate(train_dataloader):
        if step % 40 == 0 and not step == 0:
            elapsed = format_time(time.time() - t0)
            
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))

        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        model.zero_grad()        

        output = model(b_input_ids, 
                             token_type_ids=None, 
                             attention_mask=b_input_mask, 
                             labels=b_labels)
        loss = output.loss
        logits = output.logits

        total_train_loss += loss.item()

        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()

    avg_train_loss = total_train_loss / len(train_dataloader)
    
    training_time = format_time(time.time() - t0)

    print("\n  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epoch took: {:}".format(training_time))

    print("\nRunning Validation...")

    t0 = time.time()

    model.eval()

    total_eval_accuracy = 0
    total_eval_loss = 0
    nb_eval_steps = 0

    for batch in validation_dataloader:
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)
        
        with torch.no_grad():        
            output = model(b_input_ids, 
                                   token_type_ids=None, 
                                   attention_mask=b_input_mask,
                                   labels=b_labels)
            loss = output.loss
            logits = output.logits
            
        total_eval_loss += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()

        total_eval_accuracy += flat_accuracy(logits, label_ids)
        
    avg_val_accuracy = total_eval_accuracy / len(validation_dataloader)
    print("  Accuracy: {0:.2f}".format(avg_val_accuracy))

    avg_val_loss = total_eval_loss / len(validation_dataloader)
    
    validation_time = format_time(time.time() - t0)
    
    print("  Validation Loss: {0:.2f}".format(avg_val_loss))
    print("  Validation took: {:}".format(validation_time))

print("\nTraining complete!")

print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))


encoded_dict = tokenizer(
                    ["Economic war between China and USA continues", "ELDEN RING world record; game passed in 2 minutes", "calculus in a nutshell"],
                    add_special_tokens=True,
                    max_length=128,
                    truncation=True,
                    padding=True,
                    return_tensors='pt'
               )

input_ids = torch.cat([encoded_dict['input_ids']], dim=0)
attention_masks = torch.cat([encoded_dict['attention_mask']], dim=0)

prediction_data = TensorDataset(input_ids, attention_masks)
prediction_sampler = SequentialSampler(prediction_data)
prediction_dataloader = DataLoader(prediction_data, sampler=prediction_sampler, batch_size=batch_size)

#!g1.1
print('Predicting labels for {:,} test sentences...'.format(len(input_ids)))

model.eval()

predictions = []

for batch in prediction_dataloader:
    batch = tuple(t.to(device) for t in batch)
  
    b_input_ids, b_input_mask = batch
  
    with torch.no_grad():
        outputs = model(b_input_ids, token_type_ids=None, 
                      attention_mask=b_input_mask)

    logits = outputs[0]

    logits = logits.detach().cpu().numpy()

    predictions = predictions + list(np.argmax(logits, axis = 1)) 

print('    DONE.')

predictions
# Out:
# ======== Epoch 1 / 5 ========
# Training...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb 셀 12 line 7
#      <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X21sZmlsZQ%3D%3D?line=66'>67</a> logits = output.logits
#      <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X21sZmlsZQ%3D%3D?line=68'>69</a> total_train_loss += loss.item()
# ---> <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X21sZmlsZQ%3D%3D?line=70'>71</a> loss.backward()
#      <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X21sZmlsZQ%3D%3D?line=72'>73</a> torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
#      <a href='vscode-notebook-cell:/Users/juniverse/Desktop/pointcloud/VectorUniverse/youtube/test.ipynb#X21sZmlsZQ%3D%3D?line=74'>75</a> optimizer.step()
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File ~/opt/anaconda3/envs/veda/lib/python3.8/site-packages/torch/autograd/__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
dict1 = {'3Blue1Brown': {'total': 30,
  'counts': 20,
  'img_counts': 20,
  'text_counts': 6},
 'A&E': {'total': 28, 'counts': 2, 'img_counts': 2, 'text_counts': 0},
 'About To Eat': {'total': 27,
  'counts': 10,
  'img_counts': 10,
  'text_counts': 0},
 'Abroad in Japan': {'total': 30,
  'counts': 30,
  'img_counts': 21,
  'text_counts': 29},
 'Austin Evans': {'total': 28, 'counts': 6, 'img_counts': 6, 'text_counts': 0},
 'Barely Sociable': {'total': 28,
  'counts': 1,
  'img_counts': 1,
  'text_counts': 0},
 'BBC News': {'total': 6, 'counts': 6, 'img_counts': 6, 'text_counts': 0},
 'Bon Appétit': {'total': 30, 'counts': 3, 'img_counts': 3, 'text_counts': 0},
 'Brooklyn Nine-Nine': {'total': 30,
  'counts': 3,
  'img_counts': 3,
  'text_counts': 0},
 'BuzzFeedVideo': {'total': 28,
  'counts': 0,
 'img_counts': 0,
  'text_counts': 0},
 'Captain Disillusion': {'total': 30,
  'counts': 0,
  'img_counts': 0,
  'text_counts': 0},
 'Car Throttle': {'total': 26, 'counts': 0, 'img_counts': 0, 'text_counts': 0},
 'carwow': {'total': 30, 'counts': 2, 'img_counts': 2, 'text_counts': 0},
 'CDawgVA': {'total': 30, 'counts': 22, 'img_counts': 15, 'text_counts': 11},
 'ChrisFix': {'total': 29, 'counts': 4, 'img_counts': 4, 'text_counts': 0},
 'CNET': {'total': 27, 'counts': 2, 'img_counts': 2, 'text_counts': 0},
 'Coder Coder': {'total': 29,
  'counts': 14,
  'img_counts': 14,
  'text_counts': 0},
 'Doctor Who': {'total': 23, 'counts': 0, 'img_counts': 0, 'text_counts': 0},
 'Donut Media': {'total': 28, 'counts': 2, 'img_counts': 2, 'text_counts': 0},
 'Dr. Becky': {'total': 26, 'counts': 17, 'img_counts': 13, 'text_counts': 11},
 'DramaAlert': {'total': 8, 'counts': 0, 'img_counts': 0, 'text_counts': 0},
 'Drew Gooden': {'total': 30, 'counts': 0, 'img_counts': 0, 'text_counts': 0},
 'DRIVETRIBE': {'total': 19, 'counts': 8, 'img_counts': 8, 'text_counts': 0},
 'Eater': {'total': 19, 'counts': 3, 'img_counts': 3, 'text_counts': 0},
 'ElectroBOOM': {'total': 28, 'counts': 12, 'img_counts': 7, 'text_counts': 8},
 'EpicNameBro': {'total': 12,
  'counts': 12,
  'img_counts': 12,
  'text_counts': 12},
 'Epicurious': {'total': 29, 'counts': 6, 'img_counts': 6, 'text_counts': 0},
 'Fireship': {'total': 24, 'counts': 2, 'img_counts': 2, 'text_counts': 0},
 'First We Feast': {'total': 25,
  'counts': 0,
  'img_counts': 0,
  'text_counts': 0},
 'FoodTribe': {'total': 14, 'counts': 0, 'img_counts': 0, 'text_counts': 0},
 'gameranx': {'total': 25, 'counts': 25, 'img_counts': 22, 'text_counts': 24},
 'Gordon Ramsay': {'total': 29,
  'counts': 11,
  'img_counts': 10,
  'text_counts': 2},
 'Hardware Canucks': {'total': 29,
  'counts': 10,
  'img_counts': 10,
  'text_counts': 0},
 "Hell's Kitchen": {'total': 30,
  'counts': 6,
  'img_counts': 6,
  'text_counts': 0},
 'Incognito Mode': {'total': 29,
  'counts': 29,
  'img_counts': 25,
  'text_counts': 27},
 'Insider News': {'total': 26, 'counts': 2, 'img_counts': 2, 'text_counts': 0},
 'Internet Historian': {'total': 29,
  'counts': 3,
  'img_counts': 2,
  'text_counts': 2},
 'jacksepticeye': {'total': 29,
  'counts': 22,
  'img_counts': 19,
  'text_counts': 17},
 'JCS - Criminal Psychology': {'total': 13,
  'counts': 0,
  'img_counts': 0,
  'text_counts': 0},
 'Joma in NYC': {'total': 12, 'counts': 9, 'img_counts': 7, 'text_counts': 6},
 'Joma Tech': {'total': 28, 'counts': 12, 'img_counts': 12, 'text_counts': 0},
 'JRE Clips': {'total': 18, 'counts': 0, 'img_counts': 0, 'text_counts': 0},
 'Key & Peele': {'total': 30,
  'counts': 30,
  'img_counts': 19,
  'text_counts': 30},
 'Kurzgesagt – In a Nutshell': {'total': 29,
  'counts': 12,
  'img_counts': 8,
  'text_counts': 9},
 'LEMMiNO': {'total': 30, 'counts': 1, 'img_counts': 0, 'text_counts': 1},
 "Let's Game It Out": {'total': 28,
  'counts': 27,
  'img_counts': 25,
  'text_counts': 18},
 'LevelCapGaming': {'total': 27,
  'counts': 26,
  'img_counts': 21,
  'text_counts': 26},
 'Lex Clips': {'total': 27, 'counts': 20, 'img_counts': 13, 'text_counts': 14},
 'LGR': {'total': 27, 'counts': 26, 'img_counts': 23, 'text_counts': 22},
 'Linus Tech Tips': {'total': 27,
  'counts': 8,
  'img_counts': 8,
  'text_counts': 0},
 'Mark Rober': {'total': 29, 'counts': 13, 'img_counts': 8, 'text_counts': 8},
 'Markiplier': {'total': 28,
  'counts': 17,
  'img_counts': 14,
  'text_counts': 16},
 'Marques Brownlee': {'total': 25,
  'counts': 13,
  'img_counts': 13,
  'text_counts': 0},
 'MrBeast': {'total': 29, 'counts': 5, 'img_counts': 5, 'text_counts': 0},
 'Munchies': {'total': 25, 'counts': 9, 'img_counts': 8, 'text_counts': 1},
 'Mythical Kitchen': {'total': 26,
  'counts': 14,
  'img_counts': 11,
  'text_counts': 6},
 'NBC News': {'total': 23, 'counts': 10, 'img_counts': 10, 'text_counts': 0},
 'NileRed': {'total': 29, 'counts': 22, 'img_counts': 18, 'text_counts': 17},
 'NowThis News': {'total': 23, 'counts': 2, 'img_counts': 2, 'text_counts': 0},
 'OverSimplified': {'total': 27,
  'counts': 16,
  'img_counts': 16,
  'text_counts': 0},
 'Parks and Recreation': {'total': 30,
  'counts': 30,
  'img_counts': 28,
  'text_counts': 22},
 'PBS Space Time': {'total': 29,
  'counts': 25,
  'img_counts': 11,
  'text_counts': 22},
 'penguinz0': {'total': 21, 'counts': 21, 'img_counts': 6, 'text_counts': 20},
 "Sam O'Nella Academy": {'total': 29,
  'counts': 4,
  'img_counts': 4,
  'text_counts': 1},
 'Screen Junkies': {'total': 24,
  'counts': 14,
  'img_counts': 14,
  'text_counts': 1},
'SEA': {'total': 9, 'counts': 7, 'img_counts': 5, 'text_counts': 2},
 'Shroud': {'total': 20, 'counts': 17, 'img_counts': 15, 'text_counts': 15},
 'Sky News': {'total': 23, 'counts': 14, 'img_counts': 14, 'text_counts': 0},
 'SmarterEveryDay': {'total': 22,
  'counts': 9,
  'img_counts': 6,
  'text_counts': 6},
 'SomeGoodNews': {'total': 15, 'counts': 1, 'img_counts': 0, 'text_counts': 1},
 'Team Coco': {'total': 28, 'counts': 9, 'img_counts': 9, 'text_counts': 0},
 'TechLinked': {'total': 27, 'counts': 6, 'img_counts': 6, 'text_counts': 0},
 'Techquickie': {'total': 16, 'counts': 2, 'img_counts': 2, 'text_counts': 0},
 'The Daily Show with Trevor Noah': {'total': 30,
  'counts': 2,
  'img_counts': 2,
  'text_counts': 0},
 'The F Word': {'total': 14, 'counts': 7, 'img_counts': 7, 'text_counts': 0},
 'The Graham Norton Show': {'total': 29,
  'counts': 29,
  'img_counts': 28,
  'text_counts': 17},
 'The Grand Tour': {'total': 25,
  'counts': 9,
  'img_counts': 9,
  'text_counts': 0},
 'The Infographics Show': {'total': 30,
  'counts': 6,
  'img_counts': 6,
  'text_counts': 0},
 'The Office': {'total': 30, 'counts': 0, 'img_counts': 0, 'text_counts': 0},
 'The Stig': {'total': 20, 'counts': 8, 'img_counts': 8, 'text_counts': 0},
 'The Try Guys': {'total': 30, 'counts': 1, 'img_counts': 1, 'text_counts': 0},
 'TheStraightPipes': {'total': 26,
  'counts': 8,
  'img_counts': 8,
  'text_counts': 0},
 'TheWarOwl': {'total': 27, 'counts': 27, 'img_counts': 23, 'text_counts': 25},
 'Throttle House': {'total': 29,
  'counts': 0,
  'img_counts': 0,
  'text_counts': 0},
 'Top Gear': {'total': 29, 'counts': 15, 'img_counts': 15, 'text_counts': 0},
 'Veritasium': {'total': 30, 'counts': 12, 'img_counts': 10, 'text_counts': 7},
 'VICE': {'total': 19, 'counts': 2, 'img_counts': 2, 'text_counts': 0},
 'videogamedunkey': {'total': 30,
  'counts': 29,
  'img_counts': 27,
  'text_counts': 26},
 'Vox': {'total': 28, 'counts': 5, 'img_counts': 5, 'text_counts': 0},
 'Vsauce': {'total': 20, 'counts': 8, 'img_counts': 8, 'text_counts': 2},
 'Web Dev Simplified': {'total': 27,
  'counts': 0,
  'img_counts': 0,
  'text_counts': 0}}

df = pd.DataFrame(dict1)
tot = 0
img_tot = 0
text_tot = 0
for xx in list(df.columns):
    tot += df[xx]['counts']/df[xx]['total']
    img_tot += df[xx]['img_counts']/df[xx]['total']
    text_tot += df[xx]['text_counts']/df[xx]['total']

# %%
tot/len(list(df.columns)),img_tot/len(list(df.columns)),text_tot/len(list(df.columns))
# Out:
# (0.4001233604110057, 0.341821408338686, 0.20756734844457467)
